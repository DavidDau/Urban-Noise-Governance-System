# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

# %%
from preprocessing.audio_loader import load_audio
from preprocessing.cleaner import normalize_audio
from preprocessing.cleaner import remove_silence
from preprocessing.resampler import standardize_length

audio, sr = load_audio(
    "example.wav"
)

audio = remove_silence(audio)

audio = normalize_audio(audio)

audio = standardize_length(audio)

print(len(audio))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from preprocessing.audio_loader import load_audio
#       2 from preprocessing.cleaner import normalize_audio
#       3 from preprocessing.cleaner import remove_silence
#       4 from preprocessing.resampler import standardize_length
#
# File c:\Users\cyuba\Documents\LEARN\CAPSTONE\Noise\Urban-Noise-Governance-System\ml\preprocessing\audio_loader.py:1
# ----> 1 import librosa
#       2 from pathlib import Path
#       5 def load_audio(file_path, sample_rate=22050):
#
# ModuleNotFoundError: No module named 'librosa'

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\cyuba\Documents\LEARN\CAPSTONE\Noise\Urban-Noise-Governance-System\.venv\Scripts\python.exe

# %%
import librosa

print(librosa.__version__)
# Out:
# 0.11.0
